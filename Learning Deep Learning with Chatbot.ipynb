# %% [markdown]
# # Learning *Deep Learning* by creating a chatbot
#
# In this tutorial we will be creating a chat bot from scratch using deep learning.
#
# ### Basic definations used in tutorial
#
# **Utterance**: Sentence/word that user types/speaks. This is input of model.
#
# **Intent**: A class that an user utterance belongs to. This is the output of model.
#
# For example when user says *show me details about your job* to a bot, `show me details about your job` is a *utterance* and `JobDetails` can be named the intent of that utterance since user's main intent is to get detail of our job.
#
#
# We will create a deep learning model that takes an *utterance* and predicts a *intent* that this utterance falls into. Our chatbot model we trained using the data that is stored in `intents.json`.
#
#
# ## Basics of Nural Network
#
# Artificial neural network is inspired from biological neural network. Just as in biological neural network, neuron is a fundamental unit, in artificial neural network too we have a neuron. Neuron is a node in the graph that neural network creates while training itself.
#
#
# ### Layers
#
# The
#
# ### Activation Function
#
# ### Optimization Function
#
#
# The model then uses this data to learn by optimizing the loss. The learning basically means finding optimal weights needed to make prediction with lowest margin of error. Once model learns to optimize the loss using our training data, it can then predict on future data.
#
# ## Processing Data
#
# The first step of creating any deep learning model is to processing data. We process data to convert it into the format that model can digest.fed into the model.
#
#
# ### Loading Data
#
# We create a utility method named `load_data` that reades and parses the raw data stored in a given file. ( assumes the passed file is JSON ) To read the content of from given filename we use python's built in `open` function. Then to convert content of file into python's dictionary, we use `loads` function provided by `json` library. We return this dictionary so caller of this function can perferm all operations of python dictionary.
#
#
# **Function:*** A

# %%
import json

def load_data(json_file_name):
    data_file = open(json_file_name).read()
    return json.loads(data_file)

# %% [markdown]
# Now that we have a utitlity function to read data, we can use it to read the data.

# %%
file_name = 'intents.json'
data = load_data(file_name)['intents']

# %% [markdown]
# Notice we extracted `intents` out of the dictionary returned by `load_data` function and stored the list of *intents* into variable named data.

# %% [markdown]
# The data that we loaded from `intent.json` above is in human readable format. But, `keras` - the model building library we use do not support the data structure that the data currently is in. Therefore, we will need to perform pre processing on the data to make it model compatible. To achieve this, we will be using a very popular natural language processing library named `nltk` (Natural language toolkit).

# %% [markdown]
# ### Tokenization
#
# `Tokeniztion` is nothing but the process of dividing a long text into smaller chunks.
#
# A word tokenizer tokenizes a text into an array of words. The easiest way to do this is to split the text by white space. But this does not always gives the optimal result. For example, `I am a man.` can give us array `[I, am, a, man.]` when `[I, am, a man, .]` would be a better result. Since this is such a common thing we would want to do while working on parsing a text, `nltk` provides a utility method `word_tokenize` that can tokenize a text into words.
#
# A sentence tokenizer tokenizes a text into an array of sentences, and a word tokenizer divides some text into an array of words.  At first it might seem straightforward to idenify a sentence - Anything that starts with capital letter word and ends at `.` can be a sentence. So, basic intutation can be to split a text by `.` But when we esdily see from sentences like `Mr. Upen is a good person.`  that its not always straigntforward to `tokenize` a text. So, we are using `punkt` to get a pretty good tokenization of our text.
#
#
# ### Stemming and Lemmantizing
#
#
# [Here is an article that I find excellent explaining it](https://nlp.stanford.edu/IR-book/html/htmledition/stemming-and-lemmatization-1.html)
#
#
# ### Stopwords
#
# In many languages there are some words which do not add any meaning to of the sentence but rather are used for gramatical correction. For example, in `I have a ball`, `I` and `a` can be ignored to extract the root meaning of the sentene. I and a provides more context but since we have limited processing resource and time we can ignore them to simplify our model.
#
# `nltk` provides a list of `stopwords` for different language. We will have to download this resource before using it and it can be downloaded with `nltk.download('stopwords')`. Then we can find set of stopwords in english, for example, using `set(stopwords.words('english'))`

# %%
import nltk
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Gamer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Uniqueue words in all the intents
words = []
# All the possible intents in our data
intents = []

# List of tuple of [([<list of words in utterance>], '<string representing the intent>'])
word_to_intent = []

## TODO update this to actually use stopwords
stop_words =  ['.', '!'] # set(stopwords.words('english'))

def get_words_in_sentence(sentence):
    return [lemmatizer.lemmatize(w) for w in word_tokenize(sentence) if w not in stop_words]

for intent in data:
    for utterance in intent['utterances']:
        new_words = get_words_in_sentence(utterance)
        words.extend(new_words)
        
        word_to_intent.append((new_words, intent['intent']))
        
        if intent['intent'] not in intents:
            intents.append(intent['intent'])

# %% [markdown]
# ## Bag of words
#
# [Stanford NLP](https://nlp.stanford.edu/IR-book/html/htmledition/term-frequency-and-weighting-1.html)
#
# Machine learning algorithms provided by `keras` library are not compatible with stack list of strings. So, we will have to find a way to represent these list of strings into numberic array. One of the technique to convert these strings to numeric array is called *Bag of words*. The idea of bag of words to create an `N by N` array containing 0 and 1. `N` is number of unique possible word in our training set. Each of our utterance is converted to an `N by 1` array containing 1 and 0 - 0 meaning the word is not in the sentence and 1 meaning the word is in the sentence. Then the arrays created for each utterance is stacked up to create the `N by N` array (bag).
#
#
# For our example we would need two bags of words. One bag to represent utterances (X -  input that our model takes) and one to represent the corresponding intent for each utterance (Y - output that our model predicts)

# %%
unique_words = set(words)
training = []
empty_tag_bag = [0] * len(intents)

def convert_words_to_hot_bag(words):
    bag = []
    for word in unique_words:
        bag.append(1) if word in words else bag.append(0)
    return bag

def convert_sentence_to_hot_bag(sentence):
    words_in_sentence = get_words_in_sentence(sentence)
    return convert_words_to_hot_bag(words_in_sentence)
   
for word_intent in word_to_intent:
    utterance_bag = convert_words_to_hot_bag(word_intent[0])
    tag_bag = list(empty_tag_bag)
    tag_bag[intents.index(word_intent[1])] = 1
    training.append([utterance_bag, tag_bag])


import random
import numpy as np
 
random.shuffle(training)
training = np.array(training)

# create train input and label. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# Epoch 1/200
# 27/27 [==============================] - 0s 5ms/step - loss: 1.8828 - accuracy: 0.3333
# Epoch 2/200
# 27/27 [==============================] - 0s 593us/step - loss: 1.8431 - accuracy: 0.2222
# Epoch 3/200
# 27/27 [==============================] - 0s 741us/step - loss: 1.7862 - accuracy: 0.2593
# Epoch 4/200
# 27/27 [==============================] - 0s 741us/step - loss: 1.7134 - accuracy: 0.2593
# Epoch 5/200
# 27/27 [==============================] - 0s 593us/step - loss: 1.7383 - accuracy: 0.2963
# Epoch 6/200
# 27/27 [==============================] - 0s 593us/step - loss: 1.7175 - accuracy: 0.3333
# Epoch 7/200
# 27/27 [==============================] - 0s 740us/step - loss: 1.5877 - accuracy: 0.4074
# Epoch 8/200
# 27/27 [==============================] - 0s 593us/step - loss: 1.4618 - accuracy: 0.5926
# Epoch 9/200
# 27/27 [==============================] - 0s 592us/step - loss: 1.4544 - accuracy: 0.6296
# Epoch 10/200
# 27/27 [==============================] - 0s 593us/step - loss: 1.5187 - accuracy: 0.4815
# Epoch 11/200
# 27/27 [==============================] - 0s 594us/step - loss: 1.2893 - accuracy: 0.5926
# Epoch 12/200
# 27/27 [==============================] - 0s 443us/step - loss: 1.2463 - accuracy: 0.7037
# Epoch 13/200
# 27/27 [==============================] - 0s 443us/step - loss: 1.1582 - accuracy: 0.6667
# Epoch 14/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.9827 - accuracy: 0.6296
# Epoch 15/200
# 27/27 [==============================] - 0s 741us/step - loss: 1.1693 - accuracy: 0.5926
# Epoch 16/200
# 27/27 [==============================] - 0s 741us/step - loss: 0.9987 - accuracy: 0.5556
# Epoch 17/200
# 27/27 [==============================] - 0s 741us/step - loss: 0.9261 - accuracy: 0.7037
# Epoch 18/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.8824 - accuracy: 0.7037
# Epoch 19/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.8208 - accuracy: 0.7407
# Epoch 20/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.7673 - accuracy: 0.7778
# Epoch 21/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.8514 - accuracy: 0.7407
# Epoch 22/200
# 27/27 [==============================] - 0s 741us/step - loss: 0.5371 - accuracy: 0.9259
# Epoch 23/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.7636 - accuracy: 0.7778
# Epoch 24/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.5350 - accuracy: 0.7778
# Epoch 25/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.5866 - accuracy: 0.7778
# Epoch 26/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.4948 - accuracy: 0.9259
# Epoch 27/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.5224 - accuracy: 0.8889
# Epoch 28/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.4925 - accuracy: 0.8889
# Epoch 29/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.4241 - accuracy: 0.9630
# Epoch 30/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.4786 - accuracy: 0.9259
# Epoch 31/200
# 27/27 [==============================] - 0s 740us/step - loss: 0.5155 - accuracy: 0.7778
# Epoch 32/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.4877 - accuracy: 0.8889
# Epoch 33/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.4797 - accuracy: 0.7778
# Epoch 34/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.5332 - accuracy: 0.8148
# Epoch 35/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.4393 - accuracy: 0.7778
# Epoch 36/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1712 - accuracy: 0.9630
# Epoch 37/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.3744 - accuracy: 0.9259
# Epoch 38/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.3303 - accuracy: 0.9630
# Epoch 39/200
# 27/27 [==============================] - 0s 739us/step - loss: 0.3892 - accuracy: 0.8889
# Epoch 40/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.2190 - accuracy: 0.8889
# Epoch 41/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.2625 - accuracy: 0.9630
# Epoch 42/200
# 27/27 [==============================] - 0s 442us/step - loss: 0.1870 - accuracy: 1.0000
# Epoch 43/200
# 27/27 [==============================] - 0s 741us/step - loss: 0.2282 - accuracy: 0.9630
# Epoch 44/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1625 - accuracy: 0.9259
# Epoch 45/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.2123 - accuracy: 0.9630
# Epoch 46/200
# 27/27 [==============================] - 0s 741us/step - loss: 0.2420 - accuracy: 0.9630
# Epoch 47/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1986 - accuracy: 0.9630
# Epoch 48/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.2914 - accuracy: 0.8148
# Epoch 49/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.2131 - accuracy: 0.9259
# Epoch 50/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1460 - accuracy: 0.9630
# Epoch 51/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1553 - accuracy: 1.0000
# Epoch 52/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1271 - accuracy: 0.9630
# Epoch 53/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.3878 - accuracy: 0.8519
# Epoch 54/200
# 27/27 [==============================] - 0s 741us/step - loss: 0.2638 - accuracy: 1.0000
# Epoch 55/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0855 - accuracy: 1.0000
# Epoch 56/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.1918 - accuracy: 0.9630
# Epoch 57/200
# 27/27 [==============================] - 0s 445us/step - loss: 0.1851 - accuracy: 0.9630
# Epoch 58/200
# 27/27 [==============================] - 0s 742us/step - loss: 0.2153 - accuracy: 0.9259
# Epoch 59/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1934 - accuracy: 1.0000
# Epoch 60/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.1072 - accuracy: 1.0000
# Epoch 61/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1313 - accuracy: 0.9630
# Epoch 62/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1412 - accuracy: 0.9630
# Epoch 63/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1076 - accuracy: 0.9630
# Epoch 64/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.2122 - accuracy: 0.9259
# Epoch 65/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.0979 - accuracy: 0.9630
# Epoch 66/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1547 - accuracy: 0.9259
# Epoch 67/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.2424 - accuracy: 0.8519
# Epoch 68/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0774 - accuracy: 1.0000
# Epoch 69/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1472 - accuracy: 0.9630
# Epoch 70/200
# 27/27 [==============================] - 0s 445us/step - loss: 0.1021 - accuracy: 0.9630
# Epoch 71/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.1733 - accuracy: 0.9630
# Epoch 72/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1568 - accuracy: 0.9630
# Epoch 73/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1893 - accuracy: 0.9630
# Epoch 74/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.2106 - accuracy: 0.9630
# Epoch 75/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.0962 - accuracy: 1.0000
# Epoch 76/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.1187 - accuracy: 0.9630
# Epoch 77/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.0989 - accuracy: 1.0000
# Epoch 78/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 79/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1415 - accuracy: 0.9259
# Epoch 80/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0965 - accuracy: 1.0000
# Epoch 81/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 82/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0505 - accuracy: 1.0000
# Epoch 83/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1509 - accuracy: 0.9630
# Epoch 84/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1706 - accuracy: 0.9630
# Epoch 85/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0954 - accuracy: 1.0000
# Epoch 86/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 87/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0784 - accuracy: 0.9630
# Epoch 88/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 89/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 90/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0978 - accuracy: 0.9630
# Epoch 91/200
# 27/27 [==============================] - 0s 442us/step - loss: 0.1118 - accuracy: 0.9630
# Epoch 92/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0473 - accuracy: 1.0000
# Epoch 93/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 94/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.0914 - accuracy: 0.9630
# Epoch 95/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 96/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1946 - accuracy: 0.9630
# Epoch 97/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.1043 - accuracy: 0.9630
# Epoch 98/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0402 - accuracy: 1.0000
# Epoch 99/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.1412 - accuracy: 0.8889
# Epoch 100/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.0671 - accuracy: 1.0000
# Epoch 101/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0779 - accuracy: 1.0000
# Epoch 102/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 103/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0976 - accuracy: 0.9630
# Epoch 104/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0624 - accuracy: 0.9630
# Epoch 105/200
# 27/27 [==============================] - 0s 445us/step - loss: 0.0993 - accuracy: 0.9630
# Epoch 106/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.1088 - accuracy: 1.0000
# Epoch 107/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 108/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 109/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 110/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1182 - accuracy: 0.9259
# Epoch 111/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0685 - accuracy: 1.0000
# Epoch 112/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1058 - accuracy: 0.9630
# Epoch 113/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.0477 - accuracy: 1.0000
# Epoch 114/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 115/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0969 - accuracy: 0.9630
# Epoch 116/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0793 - accuracy: 1.0000
# Epoch 117/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 118/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 119/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 120/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 121/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1241 - accuracy: 0.9259
# Epoch 122/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.0423 - accuracy: 1.0000
# Epoch 123/200
# 27/27 [==============================] - 0s 446us/step - loss: 0.0852 - accuracy: 0.9630
# Epoch 124/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 125/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 126/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 127/200
# 27/27 [==============================] - 0s 590us/step - loss: 0.0690 - accuracy: 1.0000
# Epoch 128/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 129/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 130/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 131/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0605 - accuracy: 1.0000
# Epoch 132/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 133/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 134/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0629 - accuracy: 0.9630
# Epoch 135/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0972 - accuracy: 0.9630
# Epoch 136/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 137/200
# 27/27 [==============================] - 0s 740us/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 138/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 139/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 140/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 141/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 142/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0702 - accuracy: 1.0000
# Epoch 143/200
# 27/27 [==============================] - 0s 743us/step - loss: 0.0479 - accuracy: 1.0000
# Epoch 144/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 145/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.1231 - accuracy: 0.9259
# Epoch 146/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.1085 - accuracy: 0.9630
# Epoch 147/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 148/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 149/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 150/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0405 - accuracy: 1.0000
# Epoch 151/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0243 - accuracy: 1.0000
# Epoch 152/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 153/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 154/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 155/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 156/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 157/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 158/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0416 - accuracy: 0.9630
# Epoch 159/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0374 - accuracy: 0.9630
# Epoch 160/200
# 27/27 [==============================] - 0s 590us/step - loss: 0.0605 - accuracy: 1.0000
# Epoch 161/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0651 - accuracy: 0.9630
# Epoch 162/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.1250 - accuracy: 0.9630
# Epoch 163/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 164/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 165/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 166/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 167/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0532 - accuracy: 0.9630
# Epoch 168/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 169/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.1114 - accuracy: 0.9630
# Epoch 170/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 171/200
# 27/27 [==============================] - 0s 742us/step - loss: 0.0463 - accuracy: 1.0000
# Epoch 172/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 173/200
# 27/27 [==============================] - 0s 590us/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 174/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 175/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0344 - accuracy: 1.0000
# Epoch 176/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.0760 - accuracy: 1.0000
# Epoch 177/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 178/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 179/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 180/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 181/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0860 - accuracy: 0.9259
# Epoch 182/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.0812 - accuracy: 0.9630
# Epoch 183/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 184/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 185/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 186/200
# 27/27 [==============================] - 0s 591us/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 187/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0330 - accuracy: 1.0000
# Epoch 188/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 189/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 190/200
# 27/27 [==============================] - 0s 594us/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 191/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0250 - accuracy: 1.0000
# Epoch 192/200
# 27/27 [==============================] - 0s 741us/step - loss: 0.0903 - accuracy: 0.9630
# Epoch 193/200
# 27/27 [==============================] - 0s 740us/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 194/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0415 - accuracy: 1.0000
# Epoch 195/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 196/200
# 27/27 [==============================] - 0s 444us/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 197/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 198/200
# 27/27 [==============================] - 0s 592us/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 199/200
# 27/27 [==============================] - 0s 593us/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 200/200
# 27/27 [==============================] - 0s 443us/step - loss: 0.0106 - accuracy: 1.0000
# model created

# %% [markdown]
# Ablove we also downloaded `punkt` from `nltk`. `Punkt` is a `tokenizer` that tokenizes the given `text` into sentences.

# %%
def predict(utterance):
    input_bag = convert_sentence_to_hot_bag(utterance)
    res = model.predict(np.array([input_bag]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[intent, probability] for intent, probability in enumerate(res) if probability >ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": intents[r[0]], "probability": str(r[1])})
    return return_list[0]

# %%
def getResponse(utterance):
    initent = predict(utterance)['intent']
    predicted_intent_data = [i for i in data if i['intent'] == initent][0]
    possible_responses = predicted_intent_data['responses']
    return random.choice(possible_responses)

# %%
getResponse('good morning')
# Out:
# 'Hi there, nice to meet you! How may I help?'

# %%
getResponse('what school?')
# Out:
# 'Fisk Forever!'

# %%
getResponse('where did you study')
# Out:
# 'I did my undergraduate from Fisk University.'

# %%
getResponse('profession')
# Out:
# 'I am a software engineer'

# %%
getResponse('')
# Out:
# 'Hi! How can I help?'
